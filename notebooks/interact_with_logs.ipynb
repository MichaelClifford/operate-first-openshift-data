# %% [markdown]
# # Operate First Logs
#
# In this notebook, we will examine an json output of logs collected from our Operate First cluster on the MOC

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# Here we will load the sample data set stored in this repository at `data/raw/logs-ocp-moc-infra1-sample.json`. Details on how to get access to this data directly and prepare it for analysis in a jupyter notebook will be provided in a later notebook.

# %%
with open("../data/raw/logs-ocp-moc-infra1-sample.json") as f:
    data = json.load(f)

# %% [markdown]
# We know this is a fairly nested json lets take a look at its top level schema. Below, we can see that "hits.hits" is were the bulk of the data lives. Let's go ahead and drill down into that by printing out an example entry and having a look at the schema of the provided data.

# %%
json_normalize(data)
# Out:
#    took  timed_out  _shards.total  _shards.successful  _shards.skipped  \
# 0  4263      False              1                   1                0
#
#    _shards.failed  hits.total hits.max_score  \
# 0               0    42226903           None
#
#                                            hits.hits
# 0  [{'_index': 'infra-000001', '_type': '_doc', '...

# %%
data["hits"]["hits"][0]
# Out:
# {'_index': 'infra-000001',
#  '_type': '_doc',
#  '_id': 'YjcwMWIzMDctNjEyMy00OGM4LThhOGMtZTlhZTUxZjYyYTkx',
#  '_score': None,
#  '_source': {'docker': {'container_id': '320080ce67dc009f49d9674cebb957e896d4334b809acb38731001fd1951b816'},
#   'kubernetes': {'container_name': 'verify-hostname',
#    'namespace_name': 'openshift-kni-infra',
#    'pod_name': 'mdns-publisher-os-sto-2',
#    'pod_id': 'fef76c7c-fe11-435e-acfd-ee275a22a90e',
#    'host': 'os-sto-2',
#    'master_url': 'https://kubernetes.default.svc',
#    'namespace_id': '49fe831a-2307-4029-b97a-a73f950a9a73',
#    'namespace_labels': {'name': 'openshift-kni-infra',
#     'openshift_io/run-level': '1'},
#    'flat_labels': ['app=kni-infra-mdns']},
#   'message': '    cat $RUNTIMECFG_HOSTNAME_PATH',
#   'level': 'unknown',
#   'hostname': 'os-sto-2',
#   'pipeline_metadata': {'collector': {'ipaddr4': '192.12.185.132',
#     'inputname': 'fluent-plugin-systemd',
#     'name': 'fluentd',
#     'received_at': '2021-01-27T20:30:23.576240+00:00',
#     'version': '1.7.4 1.6.0'}},
#   '@timestamp': '2020-11-11T16:52:25.886052+00:00',
#   'viaq_msg_id': 'YjcwMWIzMDctNjEyMy00OGM4LThhOGMtZTlhZTUxZjYyYTkx'},
#  'sort': [1605113545886]}

# %% [markdown]
# Now that we can see all the additional data fields available to us for each log line, lets read it into a dataframe and get a sense of the distribution of values for each column

# %%
d = json_normalize(data["hits"]["hits"])
d.head()
# Out:
#          _index _type                                               _id  \
# 0  infra-000001  _doc  YjcwMWIzMDctNjEyMy00OGM4LThhOGMtZTlhZTUxZjYyYTkx
# 1  infra-000001  _doc  MGUwYzJjYjYtMzMxOC00ZWU3LWJlY2MtMTJmYjMyYjNiMzE2
# 2  infra-000001  _doc  Y2FmZjJlNDUtYTJkMS00M2ZhLWE3MDctMjViYmIyZGFmMzRk
# 3  infra-000001  _doc  NmFkMTE1MjEtYTgyOS00ODJmLWI4ZTItMmViMWZmM2FlOTRm
# 4  infra-000001  _doc  MmJlYjIxMjgtNzQ0Yy00NzFhLWE3N2MtNzYxMDhkNmYyMjg0
#
#   _score             sort                        _source.docker.container_id  \
# 0   None  [1605113545886]  320080ce67dc009f49d9674cebb957e896d4334b809acb...
# 1   None  [1605113545886]  320080ce67dc009f49d9674cebb957e896d4334b809acb...
# 2   None  [1605113545886]  320080ce67dc009f49d9674cebb957e896d4334b809acb...
# 3   None  [1605113545886]  320080ce67dc009f49d9674cebb957e896d4334b809acb...
# 4   None  [1605113545886]  320080ce67dc009f49d9674cebb957e896d4334b809acb...
#
#   _source.kubernetes.container_name _source.kubernetes.namespace_name  \
# 0                   verify-hostname               openshift-kni-infra
# 1                   verify-hostname               openshift-kni-infra
# 2                   verify-hostname               openshift-kni-infra
# 3                   verify-hostname               openshift-kni-infra
# 4                   verify-hostname               openshift-kni-infra
#
#   _source.kubernetes.pod_name             _source.kubernetes.pod_id  ...  \
# 0     mdns-publisher-os-sto-2  fef76c7c-fe11-435e-acfd-ee275a22a90e  ...
# 1     mdns-publisher-os-sto-2  fef76c7c-fe11-435e-acfd-ee275a22a90e  ...
# 2     mdns-publisher-os-sto-2  fef76c7c-fe11-435e-acfd-ee275a22a90e  ...
# 3     mdns-publisher-os-sto-2  fef76c7c-fe11-435e-acfd-ee275a22a90e  ...
# 4     mdns-publisher-os-sto-2  fef76c7c-fe11-435e-acfd-ee275a22a90e  ...
#
#   _source.pipeline_metadata.collector.inputname  \
# 0                         fluent-plugin-systemd
# 1                         fluent-plugin-systemd
# 2                         fluent-plugin-systemd
# 3                         fluent-plugin-systemd
# 4                         fluent-plugin-systemd
#
#   _source.pipeline_metadata.collector.name  \
# 0                                  fluentd
# 1                                  fluentd
# 2                                  fluentd
# 3                                  fluentd
# 4                                  fluentd
#
#   _source.pipeline_metadata.collector.received_at  \
# 0                2021-01-27T20:30:23.576240+00:00
# 1                2021-01-27T20:30:23.576490+00:00
# 2                2021-01-27T20:30:23.576866+00:00
# 3                2021-01-27T20:30:23.577231+00:00
# 4                2021-01-27T20:30:23.577348+00:00
#
#   _source.pipeline_metadata.collector.version  \
# 0                                 1.7.4 1.6.0
# 1                                 1.7.4 1.6.0
# 2                                 1.7.4 1.6.0
# 3                                 1.7.4 1.6.0
# 4                                 1.7.4 1.6.0
#
#                  _source.@timestamp  \
# 0  2020-11-11T16:52:25.886052+00:00
# 1  2020-11-11T16:52:25.886174+00:00
# 2  2020-11-11T16:52:25.886174+00:00
# 3  2020-11-11T16:52:25.886174+00:00
# 4  2020-11-11T16:52:25.886174+00:00
#
#                                 _source.viaq_msg_id  \
# 0  YjcwMWIzMDctNjEyMy00OGM4LThhOGMtZTlhZTUxZjYyYTkx
# 1  MGUwYzJjYjYtMzMxOC00ZWU3LWJlY2MtMTJmYjMyYjNiMzE2
# 2  Y2FmZjJlNDUtYTJkMS00M2ZhLWE3MDctMjViYmIyZGFmMzRk
# 3  NmFkMTE1MjEtYTgyOS00ODJmLWI4ZTItMmViMWZmM2FlOTRm
# 4  MmJlYjIxMjgtNzQ0Yy00NzFhLWE3N2MtNzYxMDhkNmYyMjg0
#
#   _source.kubernetes.container_image _source.kubernetes.container_image_id  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
# 2                                NaN                                   NaN
# 3                                NaN                                   NaN
# 4                                NaN                                   NaN
#
#   _source.kubernetes.namespace_labels.openshift_io/cluster-monitoring  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   _source.kubernetes.namespace_labels.network_openshift_io/policy-group
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 30 columns]

# %%
# two quick minor cleaning steps for df.describe function below
d["sort"] = d["sort"].apply(lambda x: x[0])
d["_source.kubernetes.flat_labels"] = d[
    "_source.kubernetes.flat_labels"
].apply(lambda x: " ".join(x))

# %%
d.columns
# Out:
# Index(['_index', '_type', '_id', '_score', 'sort',
#        '_source.docker.container_id', '_source.kubernetes.container_name',
#        '_source.kubernetes.namespace_name', '_source.kubernetes.pod_name',
#        '_source.kubernetes.pod_id', '_source.kubernetes.host',
#        '_source.kubernetes.master_url', '_source.kubernetes.namespace_id',
#        '_source.kubernetes.namespace_labels.name',
#        '_source.kubernetes.namespace_labels.openshift_io/run-level',
#        '_source.kubernetes.flat_labels', '_source.message', '_source.level',
#        '_source.hostname', '_source.pipeline_metadata.collector.ipaddr4',
#        '_source.pipeline_metadata.collector.inputname',
#        '_source.pipeline_metadata.collector.name',
#        '_source.pipeline_metadata.collector.received_at',
#        '_source.pipeline_metadata.collector.version', '_source.@timestamp',
#        '_source.viaq_msg_id', '_source.kubernetes.container_image',
#        '_source.kubernetes.container_image_id',
#        '_source.kubernetes.namespace_labels.openshift_io/cluster-monitoring',
#        '_source.kubernetes.namespace_labels.network_openshift_io/policy-group'],
#       dtype='object')

# %%
t2 = pd.to_datetime(d["_source.@timestamp"][len(d) - 1])
t1 = pd.to_datetime(d["_source.@timestamp"][0])
print(t1)
print(t2)
print(t2 - t1)
# Out:
# 2020-11-11 16:52:25.886052+00:00
# 2020-11-12 07:42:20.610002+00:00
# 0 days 14:49:54.723950

# %% [markdown]
# This particular data set contsitutes about 15 hours worth of logs between November 11th and 12th 2020.

# %%
for i in d.columns:
    print(i)
    print(d[i].describe())
    print("\n")
# Out:
# _index
# count             4198
# unique               1
# top       infra-000001
# freq              4198
# Name: _index, dtype: object
#
#
# _type
# count     4198
# unique       1
# top       _doc
# freq      4198
# Name: _type, dtype: object
#
#
# _id
# count                                                 4198
# unique                                                4198
# top       YTdiNWYwOTQtZmExZi00YjAxLTk0ZTItZTYzM2U0YzY3MWE2
# freq                                                     1
# Name: _id, dtype: object
#
#
# _score
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: _score, dtype: object
#
#
# sort
# count    4.198000e+03
# mean     1.605140e+12
# std      1.438565e+07
# min      1.605114e+12
# 25%      1.605130e+12
# 50%      1.605137e+12
# 75%      1.605152e+12
# max      1.605167e+12
# Name: sort, dtype: float64
#
#
# _source.docker.container_id
# count                                                  4198
# unique                                                   36
# top       16002711f7a50ec1f58b6a4274a32a16703f78c489e960...
# freq                                                   2707
# Name: _source.docker.container_id, dtype: object
#
#
# _source.kubernetes.container_name
# count        4198
# unique         26
# top       node-ca
# freq         2707
# Name: _source.kubernetes.container_name, dtype: object
#
#
# _source.kubernetes.namespace_name
# count                         4198
# unique                           9
# top       openshift-image-registry
# freq                          2707
# Name: _source.kubernetes.namespace_name, dtype: object
#
#
# _source.kubernetes.pod_name
# count              4198
# unique               18
# top       node-ca-dqvlh
# freq               2707
# Name: _source.kubernetes.pod_name, dtype: object
#
#
# _source.kubernetes.pod_id
# count                                     4198
# unique                                      18
# top       319e8c9f-f556-49d1-8205-35752d6bb46b
# freq                                      2707
# Name: _source.kubernetes.pod_id, dtype: object
#
#
# _source.kubernetes.host
# count         4198
# unique           1
# top       os-sto-2
# freq          4198
# Name: _source.kubernetes.host, dtype: object
#
#
# _source.kubernetes.master_url
# count                               4198
# unique                                 1
# top       https://kubernetes.default.svc
# freq                                4198
# Name: _source.kubernetes.master_url, dtype: object
#
#
# _source.kubernetes.namespace_id
# count                                     4198
# unique                                       9
# top       df8564b3-da20-4d19-abe1-f85bf9ad1c7e
# freq                                      2707
# Name: _source.kubernetes.namespace_id, dtype: object
#
#
# _source.kubernetes.namespace_labels.name
# count                                   465
# unique                                    4
# top       openshift-machine-config-operator
# freq                                    297
# Name: _source.kubernetes.namespace_labels.name, dtype: object
#
#
# _source.kubernetes.namespace_labels.openshift_io/run-level
# count     1099
# unique       2
# top          0
# freq       745
# Name: _source.kubernetes.namespace_labels.openshift_io/run-level, dtype: object
#
#
# _source.kubernetes.flat_labels
# count                                                  4198
# unique                                                   17
# top       controller-revision-hash=84ddc6db9c name=node-...
# freq                                                   2707
# Name: _source.kubernetes.flat_labels, dtype: object
#
#
# _source.message
# count                                                  4198
# unique                                                 1391
# top       image-registry.openshift-image-registry.svc..5000
# freq                                                    677
# Name: _source.message, dtype: object
#
#
# _source.level
# count        4198
# unique          1
# top       unknown
# freq         4198
# Name: _source.level, dtype: object
#
#
# _source.hostname
# count         4198
# unique           1
# top       os-sto-2
# freq          4198
# Name: _source.hostname, dtype: object
#
#
# _source.pipeline_metadata.collector.ipaddr4
# count               4198
# unique                 1
# top       192.12.185.132
# freq                4198
# Name: _source.pipeline_metadata.collector.ipaddr4, dtype: object
#
#
# _source.pipeline_metadata.collector.inputname
# count                      4198
# unique                        1
# top       fluent-plugin-systemd
# freq                       4198
# Name: _source.pipeline_metadata.collector.inputname, dtype: object
#
#
# _source.pipeline_metadata.collector.name
# count        4198
# unique          1
# top       fluentd
# freq         4198
# Name: _source.pipeline_metadata.collector.name, dtype: object
#
#
# _source.pipeline_metadata.collector.received_at
# count                                 4198
# unique                                4198
# top       2021-01-27T20:31:46.457479+00:00
# freq                                     1
# Name: _source.pipeline_metadata.collector.received_at, dtype: object
#
#
# _source.pipeline_metadata.collector.version
# count            4198
# unique              1
# top       1.7.4 1.6.0
# freq             4198
# Name: _source.pipeline_metadata.collector.version, dtype: object
#
#
# _source.@timestamp
# count                                 4198
# unique                                3720
# top       2020-11-11T21:37:13.123062+00:00
# freq                                    48
# Name: _source.@timestamp, dtype: object
#
#
# _source.viaq_msg_id
# count                                                 4198
# unique                                                4198
# top       YTdiNWYwOTQtZmExZi00YjAxLTk0ZTItZTYzM2U0YzY3MWE2
# freq                                                     1
# Name: _source.viaq_msg_id, dtype: object
#
#
# _source.kubernetes.container_image
# count                                                  4022
# unique                                                   14
# top       quay.io/openshift-release-dev/ocp-v4.0-art-dev...
# freq                                                   2707
# Name: _source.kubernetes.container_image, dtype: object
#
#
# _source.kubernetes.container_image_id
# count                                                  4022
# unique                                                   14
# top       quay.io/openshift-release-dev/ocp-v4.0-art-dev...
# freq                                                   2707
# Name: _source.kubernetes.container_image_id, dtype: object
#
#
# _source.kubernetes.namespace_labels.openshift_io/cluster-monitoring
# count     4012
# unique       1
# top       true
# freq      4012
# Name: _source.kubernetes.namespace_labels.openshift_io/cluster-monitoring, dtype: object
#
#
# _source.kubernetes.namespace_labels.network_openshift_io/policy-group
# count             86
# unique             1
# top       monitoring
# freq              86
# Name: _source.kubernetes.namespace_labels.network_openshift_io/policy-group, dtype: object

# %% [markdown]
# Now that we've looked at the different columns availble to us, let's go ahead and aggregate all the log messages by their pod and print out a sample set of logs.

# %%
d[["_source.kubernetes.pod_name", "_source.message"]].groupby(
    "_source.kubernetes.pod_name"
)["_source.message"].apply(list)
# Out:
# _source.kubernetes.pod_name
# coredns-os-sto-2                                      ['''time='2020-11-11T165225Z' level=info msg='...
# csi-cephfsplugin-vxkbf                                [I1111 18:37:17.313016       1 main.go:110] Ve...
# csi-rbdplugin-69f9n                                   [I1111 18:37:17.309147  181203 main.go:110] Ve...
# dns-default-jbm9m                                     [I1111 16:53:28.822629       1 main.go:186] Va...
# keepalived-os-sto-2                                   ['''time='2020-11-11T165230Z' level=info msg='...
# machine-config-daemon-mq4zb                           [I1111 16:53:00.178261    4288 start.go:74] Ve...
# mdns-publisher-os-sto-2                               [    cat $RUNTIMECFG_HOSTNAME_PATH,     # if h...
# multus-c9kjx                                          [Successfully copied files in /usr/src/multus-...
# node-ca-dqvlh                                         [image-registry.openshift-image-registry.svc.....
# node-exporter-x2ps5                                   ['''time='2020-11-11T165306Z' level=info msg='...
# ovnkube-node-rfdrb                                    [2020-11-11T16:53:06Z|00001|reconnect|INFO|uni...
# ovs-node-qwbl2                                        [/etc/openvswitch/conf.db does not exist ... (...
# rook-ceph-crashcollector-os-sto-2-58545c5cc9-r424g    [ownership of '/var/log/ceph/ocs-deviceset-0-d...
# rook-ceph-mon-b-775668884-qqtm5                       [ownership of '/var/log/ceph/ceph-volume.log' ...
# rook-ceph-osd-0-85d8ccfc7f-7mf8t                      [inferring bluefs devices from bluestore path,...
# rook-ceph-osd-2-54bfbcc597-fjnm2                      [inferring bluefs devices from bluestore path,...
# rook-ceph-osd-3-8db49f7cf-5pl4d                       [inferring bluefs devices from bluestore path,...
# tuned-xntz9                                           ['''I1111 165330.322245    4570 trace.go116] T...
# Name: _source.message, dtype: object

# %%
logs = (
    d[["_source.kubernetes.pod_name", "_source.message"]]
    .groupby("_source.kubernetes.pod_name")["_source.message"]
    .apply(list)
)

# %%
logs.loc["machine-config-daemon-mq4zb"]
# Out:
# ['I1111 16:53:00.178261    4288 start.go:74] Version: v4.5.0-202010230137.p0-dirty (3b284da53fa0fffd88d2825457ccc346a08a01e8)',
#  "'''I1111 165300.184240    4288 start.go84] Calling chroot('/rootfs')'''",
#  'I1111 16:53:00.184580    4288 rpm-ostree.go:369] Running captured: rpm-ostree status --json',
#  'I1111 16:53:00.394364    4288 daemon.go:210] Booted osImageURL: quay.io/openshift-release-dev/ocp-v4.0-art-dev@sha256:5702da70ec55deb88af71a7d186caf6131452d6e8d3def37c88f0ccdcf49f1b9 (45.82.202010250529-0)',
#  'I1111 16:53:00.397281    4288 metrics.go:106] Registering Prometheus metrics',
#  'I1111 16:53:00.397401    4288 metrics.go:111] Starting metrics listener on 127.0.0.1:8797',
#  'I1111 16:53:00.399386    4288 update.go:1419] Starting to manage node: os-sto-2',
#  'I1111 16:53:00.404725    4288 rpm-ostree.go:369] Running captured: rpm-ostree status',
#  'I1111 16:53:00.452237    4288 daemon.go:813] State: idle',
#  'Deployments:',
#  '* pivot://quay.io/openshift-release-dev/ocp-v4.0-art-dev@sha256:5702da70ec55deb88af71a7d186caf6131452d6e8d3def37c88f0ccdcf49f1b9',
#  '              CustomOrigin: Managed by machine-config-operator',
#  '                   Version: 45.82.202010250529-0 (2020-10-25T05:34:03Z)',
#  '',
#  '  ostree://f9d88d07921009f524c39773d0935a7d1642a02bd37e0d621696bf4f766a0540',
#  '                   Version: 45.82.202008010929-0 (2020-08-01T09:33:23Z)',
#  'I1111 16:53:00.452253    4288 rpm-ostree.go:369] Running captured: journalctl --list-boots',
#  'I1111 16:53:00.459300    4288 daemon.go:820] journalctl --list-boots:',
#  '-1 61d91031e3fe46c7997ade51641917e9 Wed 2020-11-11 16:46:26 UTC—Wed 2020-11-11 16:48:22 UTC',
#  ' 0 dc74d33fdcbc41849bf1f5013f48dbb5 Wed 2020-11-11 16:51:58 UTC—Wed 2020-11-11 16:53:00 UTC',
#  'I1111 16:53:00.459319    4288 daemon.go:567] Starting MachineConfigDaemon',
#  'I1111 16:53:00.459444    4288 daemon.go:574] Enabling Kubelet Healthz Monitor',
#  '2020/11/11 16:53:08 provider.go:119: Defaulting client-id to system:serviceaccount:openshift-machine-config-operator:machine-config-daemon',
#  '2020/11/11 16:53:08 provider.go:124: Defaulting client-secret to service account token /var/run/secrets/kubernetes.io/serviceaccount/token',
#  '2020/11/11 16:53:08 provider.go:313: Delegation of authentication and authorization to OpenShift is enabled for bearer tokens and client certificates.',
#  "'''I1111 165330.401444    4288 trace.go116] Trace[1106410694] 'Reflector ListAndWatch' namek8s.io/client-go/informers/factory.go135 (started 2020-11-11 165300.399988358 +0000 UTC m=+0.263450370) (total time 30.001407319s)'''",
#  'Trace[1106410694]: [30.001407319s] [30.001407319s] END',
#  'E1111 16:53:30.401475    4288 reflector.go:178] k8s.io/client-go/informers/factory.go:135: Failed to list *v1.Node: Get https://172.30.0.1:443/api/v1/nodes?limit=500&resourceVersion=0: dial tcp 172.30.0.1:443: i/o timeout',
#  "'''I1111 165330.401445    4288 trace.go116] Trace[646203300] 'Reflector ListAndWatch' namegithub.com/openshift/machine-config-operator/pkg/generated/informers/externalversions/factory.go101 (started 2020-11-11 165300.400165826 +0000 UTC m=+0.263627808) (total time 30.001227356s)'''",
#  'Trace[646203300]: [30.001227356s] [30.001227356s] END',
#  'E1111 16:53:30.401595    4288 reflector.go:178] github.com/openshift/machine-config-operator/pkg/generated/informers/externalversions/factory.go:101: Failed to list *v1.MachineConfig: Get https://172.30.0.1:443/apis/machineconfiguration.openshift.io/v1/machineconfigs?limit=500&resourceVersion=0: dial tcp 172.30.0.1:443: i/o timeout',
#  "'''I1111 165331.418845    4288 node.go24] No machineconfiguration.openshift.io/currentConfig annotation on node os-sto-2 map[k8s.ovn.org/l3-gateway-config{'default'{'mode''local','interface-id''br-local_os-sto-2','mac-address''0000a9fe2102','ip-addresses'['169.254.33.2/24'],'ip-address''169.254.33.2/24','next-hops'['169.254.33.1'],'next-hop''169.254.33.1','node-port-enable''true'}} k8s.ovn.org/node-chassis-id2b3d0f57-d303-4586-a5d4-9f30b76ddb49 k8s.ovn.org/node-join-subnets{'default''100.64.8.0/29'} k8s.ovn.org/node-mgmt-port-mac-addressd621a4528851 k8s.ovn.org/node-subnets{'default''10.128.4.0/23'} machine.openshift.io/machineopenshift-machine-api/cnv-storage-0-h9mw7 volumes.kubernetes.io/controller-managed-attach-detachtrue], in cluster bootstrap, loading initial node annotation from /etc/machine-config-daemon/node-annotations.json'''",
#  'I1111 16:53:31.419290    4288 node.go:45] Setting initial node config: rendered-worker-1e91fa86f1c8f66fffd9b67ddc4caa81',
#  'I1111 16:53:31.437715    4288 daemon.go:731] In bootstrap mode',
#  'I1111 16:53:31.437753    4288 daemon.go:759] Current+desired config: rendered-worker-1e91fa86f1c8f66fffd9b67ddc4caa81',
#  'I1111 16:53:31.442658    4288 daemon.go:975] No bootstrap pivot required; unlinking bootstrap node annotations',
#  'I1111 16:53:31.442730    4288 daemon.go:1013] Validating against pending config rendered-worker-1e91fa86f1c8f66fffd9b67ddc4caa81',
#  'I1111 16:53:31.893375    4288 daemon.go:1029] Validated on-disk state',
#  'I1111 16:53:31.905682    4288 daemon.go:1063] Completing pending config rendered-worker-1e91fa86f1c8f66fffd9b67ddc4caa81',
#  'I1111 16:53:31.905699    4288 update.go:1419] completed update for config rendered-worker-1e91fa86f1c8f66fffd9b67ddc4caa81',
#  'I1111 16:53:31.910032    4288 daemon.go:1079] In desired config rendered-worker-1e91fa86f1c8f66fffd9b67ddc4caa81',
#  '2020/11/11 16:53:38 provider.go:328: unable to retrieve authentication information for tokens: Post https://172.30.0.1:443/apis/authentication.k8s.io/v1/tokenreviews: dial tcp 172.30.0.1:443: i/o timeout',
#  "'''2020/11/11 165340 oauthproxy.go200 mapping path '/' => upstream 'http//127.0.0.18797/''''",
#  '2020/11/11 16:53:40 oauthproxy.go:237: Cookie settings: name:_oauth_proxy secure(https):true httponly:true expiry:168h0m0s domain:<default> refresh:disabled',
#  '2020/11/11 16:53:40 oauthproxy.go:227: OAuthProxy configured for  Client ID: system:serviceaccount:openshift-machine-config-operator:machine-config-daemon',
#  '2020/11/11 16:53:40 http.go:61: HTTP: listening on 127.0.0.1:4180',
#  'I1111 16:53:40.522599    5203 dynamic_serving_content.go:129] Starting serving::/etc/tls/private/tls.crt::/etc/tls/private/tls.key',
#  '2020/11/11 16:53:40 http.go:107: HTTPS: listening on [::]:9001',
#  'I1111 21:30:06.236301    4288 update.go:313] Checking Reconcilable for config rendered-worker-1e91fa86f1c8f66fffd9b67ddc4caa81 to rendered-worker-db7587ea9813133d6a0afc32f718af56',
#  'I1111 21:30:07.139708    4288 update.go:513] user data to be verified before ssh update: {<nil>  []  core false false false <nil>  [ssh-rsa  lars@oddbit.com ssh-rsa  naved001@bu.edu ssh-rsa ... lars@redhat.com ssh-rsa ...  lars@phone]  false <nil>}',
#  'I1111 21:30:07.139777    4288 update.go:587] SSH Keys reconcilable',
#  'I1111 21:30:08.023117    4288 update.go:1419] Starting update from rendered-worker-1e91fa86f1c8f66fffd9b67ddc4caa81 to rendered-worker-db7587ea9813133d6a0afc32f718af56: &{osUpdate:false kargs:false fips:false passwd:true files:false units:false kernelType:false}',
#  'I1111 21:30:08.028089    4288 update.go:1419] Update prepared; beginning drain',
#  'E1111 21:30:09.940406    4288 daemon.go:320] WARNING: ignoring DaemonSet-managed Pods: local-storage/localblock-local-diskmaker-dvkg7, local-storage/localblock-local-provisioner-tbvwq, metallb-system/speaker-bqrlb, openshift-cluster-node-tuning-operator/tuned-xntz9, openshift-cnv/bridge-marker-7kmql, openshift-cnv/kube-cni-linux-bridge-plugin-6r9n6, openshift-cnv/kubevirt-node-labeller-r77lc, openshift-cnv/nmstate-handler-8kbdj, openshift-cnv/ovs-cni-amd64-v2xjv, openshift-cnv/virt-handler-b45mq, openshift-dns/dns-default-jbm9m, openshift-image-registry/node-ca-dqvlh, openshift-machine-config-operator/machine-config-daemon-mq4zb, openshift-monitoring/node-exporter-x2ps5, openshift-multus/multus-c9kjx, openshift-ovn-kubernetes/ovnkube-node-rfdrb, openshift-ovn-kubernetes/ovs-node-qwbl2, openshift-storage/csi-cephfsplugin-vxkbf, openshift-storage/csi-rbdplugin-69f9n',
#  'I1111 21:30:09.945642    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-mon-b-775668884-hw8jt',
#  'I1111 21:30:09.945758    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  'I1111 21:30:09.945830    4288 daemon.go:320] evicting pod openshift-storage/noobaa-db-0',
#  'I1111 21:30:09.945856    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-operator-5745b7d49-l5ln5',
#  'I1111 21:30:09.945898    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:30:09.945915    4288 daemon.go:320] evicting pod openshift-cnv/virt-controller-8555ff4688-8wxfv',
#  'I1111 21:30:09.945931    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-prepare-ocs-deviceset-0-data-1-kjvfq-knr6q',
#  'I1111 21:30:09.945948    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-drain-canary-os-sto-2-74c486d47b-tk7xn',
#  'I1111 21:30:09.945959    4288 daemon.go:320] evicting pod openshift-image-registry/image-registry-78cd486cd8-cpx7j',
#  'I1111 21:30:09.945990    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-crashcollector-os-sto-2-58545c5cc9-n76nn',
#  'I1111 21:30:09.945991    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  'I1111 21:30:09.945957    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-mds-ocs-storagecluster-cephfilesystem-a-b44fc6b57x22x',
#  'I1111 21:30:09.946042    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-prepare-ocs-deviceset-0-data-2-b2gqz-zg2lp',
#  'I1111 21:30:09.945898    4288 daemon.go:320] evicting pod moc-ops/netbox-nginx-cd84d4f78-q7cdv',
#  'I1111 21:30:09.946160    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-rgw-ocs-storagecluster-cephobjectstore-a-7d5495fvfqbj',
#  'I1111 21:30:09.946129    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-prepare-ocs-deviceset-0-data-0-lcwsx-r8vnz',
#  'I1111 21:30:09.946218    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-tools-5447f4549-85q24',
#  "'''E1111 213009.955322    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213009.955323    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:09.966414    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-osd-prepare-ocs-deviceset-0-data-1-kjvfq-knr6q',
#  "'''E1111 213010.152386    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:10.558788    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-osd-prepare-ocs-deviceset-0-data-2-b2gqz-zg2lp',
#  'I1111 21:30:10.964314    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-osd-prepare-ocs-deviceset-0-data-0-lcwsx-r8vnz',
#  'I1111 21:30:11.146116    4288 request.go:621] Throttling request took 1.199807677s, request: POST:https://172.30.0.1:443/api/v1/namespaces/openshift-storage/pods/rook-ceph-tools-5447f4549-85q24/eviction',
#  'I1111 21:30:14.560009    4288 daemon.go:306] Evicted pod openshift-image-registry/image-registry-78cd486cd8-cpx7j',
#  'I1111 21:30:14.760231    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-drain-canary-os-sto-2-74c486d47b-tk7xn',
#  'I1111 21:30:14.955525    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:30:14.955526    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  "'''E1111 213014.961368    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213014.961903    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:15.152597    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213015.158539    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:15.159992    4288 daemon.go:306] Evicted pod openshift-storage/noobaa-db-0',
#  'I1111 21:30:15.359490    4288 daemon.go:306] Evicted pod openshift-cnv/virt-controller-8555ff4688-8wxfv',
#  'I1111 21:30:15.759717    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-mon-b-775668884-hw8jt',
#  'I1111 21:30:16.159759    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-operator-5745b7d49-l5ln5',
#  'I1111 21:30:19.961556    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:30:19.962057    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  "'''E1111 213019.967433    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213019.968156    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:20.158691    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213020.165182    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:24.359833    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-tools-5447f4549-85q24',
#  'I1111 21:30:24.959158    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-rgw-ocs-storagecluster-cephobjectstore-a-7d5495fvfqbj',
#  'I1111 21:30:24.967556    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:30:24.968280    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  "'''E1111 213024.973993    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213024.974648    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:25.159503    4288 daemon.go:306] Evicted pod moc-ops/netbox-nginx-cd84d4f78-q7cdv',
#  'I1111 21:30:25.165328    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213025.172694    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:29.974129    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:30:29.974796    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  "'''E1111 213029.980419    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213029.980644    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:30.172831    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213030.178956    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:34.980576    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:30:34.980800    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  "'''E1111 213034.986477    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213034.986983    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:35.179078    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213035.185703    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:39.986632    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:30:39.987108    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  "'''E1111 213039.993439    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213039.993439    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:40.185841    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213040.192800    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:44.973506    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-crashcollector-os-sto-2-58545c5cc9-n76nn',
#  'I1111 21:30:44.976312    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-mds-ocs-storagecluster-cephfilesystem-a-b44fc6b57x22x',
#  'I1111 21:30:44.993623    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  'I1111 21:30:44.993624    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  "'''E1111 213044.999688    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213045.000064    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:45.192924    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213045.198906    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:49.999880    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  'I1111 21:30:50.000196    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  "'''E1111 213050.007120    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213050.007129    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:50.199106    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213050.206048    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:55.007285    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  'I1111 21:30:55.007331    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  "'''E1111 213055.014015    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213055.014217    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:30:55.206234    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213055.213718    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:31:00.014216    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:31:00.014377    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  "'''E1111 213100.021161    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213100.021327    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:31:00.213908    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213100.220824    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:31:05.021302    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:31:05.021473    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  "'''E1111 213105.028464    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213105.028464    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:31:05.220934    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213105.228238    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:31:10.028630    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:31:10.028630    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  "'''E1111 213110.035300    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213110.035621    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:31:10.228370    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213110.236075    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:31:15.035466    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:31:15.035827    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  "'''E1111 213115.042719    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213115.042720    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:31:15.236234    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213115.243161    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:31:20.042887    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:31:20.042887    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  "'''E1111 213120.050854    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-0-85d8ccfc7f-9c4zs' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  "'''E1111 213120.051100    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-2-54bfbcc597-xbwxf' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:31:20.243292    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  "'''E1111 213120.250080    4288 daemon.go320] error when evicting pod 'rook-ceph-osd-3-8db49f7cf-njf9m' (will retry after 5s) Cannot evict pod as it would violate the pod's disruption budget.'''",
#  'I1111 21:31:25.051016    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:31:25.051215    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  'I1111 21:31:25.250221    4288 daemon.go:320] evicting pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  'I1111 21:31:34.266871    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-osd-3-8db49f7cf-njf9m',
#  'I1111 21:31:35.067429    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-osd-2-54bfbcc597-xbwxf',
#  'I1111 21:31:35.067429    4288 daemon.go:306] Evicted pod openshift-storage/rook-ceph-osd-0-85d8ccfc7f-9c4zs',
#  'I1111 21:31:35.067485    4288 update.go:1419] drain complete',
#  'I1111 21:31:35.071088    4288 update.go:219] Successful drain took 87.040104884 seconds',
#  'I1111 21:31:35.071122    4288 update.go:828] Updating files',
#  "'''I1111 213135.944356    4288 update.go1128] Writing file '/etc/NetworkManager/dispatcher.d/40-mdns-hostname''''",
#  "'''I1111 213135.947964    4288 update.go1128] Writing file '/etc/NetworkManager/dispatcher.d/30-resolv-prepender''''",
#  "'''I1111 213135.949990    4288 update.go1128] Writing file '/etc/pki/ca-trust/source/anchors/openshift-config-user-ca-bundle.crt''''",
#  "'''I1111 213135.952513    4288 update.go1128] Writing file '/etc/NetworkManager/conf.d/99-kni.conf''''",
#  "'''I1111 213135.954616    4288 update.go1128] Writing file '/etc/kubernetes/static-pod-resources/coredns/Corefile.tmpl''''",
#  "'''I1111 213135.956547    4288 update.go1128] Writing file '/etc/kubernetes/manifests/coredns.yaml''''",
#  "'''I1111 213135.958413    4288 update.go1128] Writing file '/etc/kubernetes/static-pod-resources/keepalived/keepalived.conf.tmpl''''",
#  "'''I1111 213135.960303    4288 update.go1128] Writing file '/etc/kubernetes/manifests/keepalived.yaml''''",
#  "'''I1111 213135.963601    4288 update.go1128] Writing file '/etc/kubernetes/static-pod-resources/mdns/config.hcl.tmpl''''",
#  "'''I1111 213135.966064    4288 update.go1128] Writing file '/etc/kubernetes/manifests/mdns-publisher.yaml''''",
#  "'''I1111 213135.968124    4288 update.go1128] Writing file '/etc/tmpfiles.d/cleanup-cni.conf''''",
#  "'''I1111 213135.970088    4288 update.go1128] Writing file '/etc/kubernetes/static-pod-resources/configmaps/cloud-config/ca-bundle.pem''''",
#  "'''I1111 213135.971980    4288 update.go1128] Writing file '/etc/containers/storage.conf''''",
#  "'''I1111 213135.974091    4288 update.go1128] Writing file '/etc/dhcp/dhclient.conf''''",
#  "'''I1111 213135.976229    4288 update.go1128] Writing file '/etc/NetworkManager/dispatcher.d/90-long-hostname''''",
#  "'''I1111 213135.978152    4288 update.go1128] Writing file '/etc/systemd/system/crio.service.d/20-stream-address.conf''''",
#  "'''I1111 213135.980302    4288 update.go1128] Writing file '/etc/modules-load.d/iptables.conf''''",
#  "'''I1111 213135.982275    4288 update.go1128] Writing file '/etc/kubernetes/kubelet-ca.crt''''",
#  "'''I1111 213135.984517    4288 update.go1128] Writing file '/etc/systemd/system.conf.d/kubelet-cgroups.conf''''",
#  "'''I1111 213135.986310    4288 update.go1128] Writing file '/etc/NetworkManager/conf.d/sdn.conf''''",
#  "'''I1111 213135.988161    4288 update.go1128] Writing file '/var/lib/kubelet/config.json''''",
#  "'''I1111 213135.990191    4288 update.go1128] Writing file '/etc/kubernetes/ca.crt''''",
#  "'''I1111 213135.992132    4288 update.go1128] Writing file '/etc/sysctl.d/forward.conf''''",
#  "'''I1111 213135.994129    4288 update.go1128] Writing file '/etc/sysctl.d/inotify.conf''''",
#  "'''I1111 213135.995901    4288 update.go1128] Writing file '/usr/local/sbin/set-valid-hostname.sh''''",
#  "'''I1111 213135.998260    4288 update.go1128] Writing file '/etc/kubernetes/kubelet-plugins/volume/exec/.dummy''''",
#  "'''I1111 213135.999983    4288 update.go1128] Writing file '/etc/containers/registries.conf''''",
#  "'''I1111 213136.001740    4288 update.go1128] Writing file '/etc/crio/crio.conf.d/00-default''''",
#  "'''I1111 213136.003662    4288 update.go1128] Writing file '/etc/containers/policy.json''''",
#  "'''I1111 213136.005390    4288 update.go1128] Writing file '/etc/kubernetes/cloud.conf''''",
#  "'''I1111 213136.006984    4288 update.go1128] Writing file '/etc/kubernetes/kubelet.conf''''",
#  "'''I1111 213136.008775    4288 update.go1128] Writing file '/etc/containers/registries.conf''''",
#  "'''I1111 213136.009197    4288 update.go1128] Writing file '/etc/crio/crio.conf.d/01-mc-defaultCapabilities''''",
#  "'''I1111 213136.011016    4288 update.go1043] Writing systemd unit dropin '10-mco-default-env.conf''''",
#  "'''I1111 213136.012130    4288 update.go1100] Enabling systemd unit 'crio.service''''",
#  "'''I1111 213136.012146    4288 update.go1043] Writing systemd unit dropin '10-mco-default-env.conf''''",
#  "'''I1111 213136.012507    4288 update.go1100] Enabling systemd unit 'kubelet.service''''",
#  "'''I1111 213136.012520    4288 update.go1043] Writing systemd unit dropin '10-mco-default-env.conf''''",
#  "'''I1111 213136.012883    4288 update.go1100] Enabling systemd unit 'machine-config-daemon-host.service''''",
#  "'''I1111 213136.012897    4288 update.go1043] Writing systemd unit dropin '10-mco-default-env.conf''''",
#  "'''I1111 213136.013259    4288 update.go1100] Enabling systemd unit 'pivot.service''''",
#  "'''I1111 213136.013275    4288 update.go1078] Writing systemd unit 'machine-config-daemon-firstboot-v42.service''''",
#  "'''I1111 213136.013661    4288 update.go1100] Enabling systemd unit 'machine-config-daemon-firstboot-v42.service''''",
#  'I1111 21:31:36.013825    4288 update.go:1006] /etc/systemd/system/multi-user.target.wants/machine-config-daemon-firstboot-v42.service already exists. Not making a new symlink',
#  "'''I1111 213136.013841    4288 update.go1078] Writing systemd unit 'machine-config-daemon-firstboot.service''''",
#  "'''I1111 213136.014216    4288 update.go1100] Enabling systemd unit 'machine-config-daemon-firstboot.service''''",
#  'I1111 21:31:36.014239    4288 update.go:1006] /etc/systemd/system/multi-user.target.wants/machine-config-daemon-firstboot.service already exists. Not making a new symlink',
#  "'''I1111 213136.014248    4288 update.go1078] Writing systemd unit 'machine-config-daemon-host.service''''",
#  "'''I1111 213136.014596    4288 update.go1100] Enabling systemd unit 'machine-config-daemon-host.service''''",
#  'I1111 21:31:36.014623    4288 update.go:1026] /etc/systemd/system/multi-user.target.wants/machine-config-daemon-host.service was not present. No need to remove',
#  "'''I1111 213136.014641    4288 update.go1078] Writing systemd unit 'node-valid-hostname.service''''",
#  "'''I1111 213136.014974    4288 update.go1100] Enabling systemd unit 'node-valid-hostname.service''''",
#  'I1111 21:31:36.014995    4288 update.go:1006] /etc/systemd/system/multi-user.target.wants/node-valid-hostname.service already exists. Not making a new symlink',
#  "'''I1111 213136.015004    4288 update.go1078] Writing systemd unit 'nodeip-configuration.service''''",
#  "'''I1111 213136.015333    4288 update.go1100] Enabling systemd unit 'nodeip-configuration.service''''",
#  'I1111 21:31:36.015354    4288 update.go:1006] /etc/systemd/system/multi-user.target.wants/nodeip-configuration.service already exists. Not making a new symlink',
#  "'''I1111 213136.015363    4288 update.go1078] Writing systemd unit 'kubelet.service''''",
#  "'''I1111 213136.015693    4288 update.go1100] Enabling systemd unit 'kubelet.service''''",
#  'I1111 21:31:36.015725    4288 update.go:1006] /etc/systemd/system/multi-user.target.wants/kubelet.service already exists. Not making a new symlink',
#  'I1111 21:31:36.015732    4288 update.go:865] Deleting stale data',
#  "'''I1111 213136.884962    4288 update.go1243] Writing SSHKeys at '/home/core/.ssh/authorized_keys''''",
#  'I1111 21:31:36.891524    4288 update.go:1419] initiating reboot: Node will reboot into config rendered-worker-db7587ea9813133d6a0afc32f718af56',
#  'I1111 21:31:37.612107    4288 daemon.go:592] Shutting down MachineConfigDaemon',
#  'I1111 21:37:09.634784    4437 start.go:74] Version: v4.5.0-202010230137.p0-dirty (3b284da53fa0fffd88d2825457ccc346a08a01e8)',
#  "'''I1111 213709.655328    4437 start.go84] Calling chroot('/rootfs')'''",
#  'I1111 21:37:09.657066    4437 rpm-ostree.go:369] Running captured: rpm-ostree status --json',
#  '2020/11/11 21:37:09 provider.go:119: Defaulting client-id to system:serviceaccount:openshift-machine-config-operator:machine-config-daemon',
#  '2020/11/11 21:37:09 provider.go:124: Defaulting client-secret to service account token /var/run/secrets/kubernetes.io/serviceaccount/token',
#  '2020/11/11 21:37:09 provider.go:313: Delegation of authentication and authorization to OpenShift is enabled for bearer tokens and client certificates.',
#  'I1111 21:37:10.036470    4437 daemon.go:210] Booted osImageURL: quay.io/openshift-release-dev/ocp-v4.0-art-dev@sha256:5702da70ec55deb88af71a7d186caf6131452d6e8d3def37c88f0ccdcf49f1b9 (45.82.202010250529-0)',
#  'I1111 21:37:10.042104    4437 metrics.go:106] Registering Prometheus metrics',
#  'I1111 21:37:10.042247    4437 metrics.go:111] Starting metrics listener on 127.0.0.1:8797',
#  'I1111 21:37:10.049424    4437 update.go:1419] Starting to manage node: os-sto-2',
#  'I1111 21:37:10.054544    4437 rpm-ostree.go:369] Running captured: rpm-ostree status',
#  'I1111 21:37:10.125359    4437 daemon.go:813] State: idle',
#  'Deployments:',
#  '* pivot://quay.io/openshift-release-dev/ocp-v4.0-art-dev@sha256:5702da70ec55deb88af71a7d186caf6131452d6e8d3def37c88f0ccdcf49f1b9',
#  '              CustomOrigin: Managed by machine-config-operator',
#  '                   Version: 45.82.202010250529-0 (2020-10-25T05:34:03Z)',
#  '',
#  '  ostree://f9d88d07921009f524c39773d0935a7d1642a02bd37e0d621696bf4f766a0540',
#  '                   Version: 45.82.202008010929-0 (2020-08-01T09:33:23Z)',
#  'I1111 21:37:10.125389    4437 rpm-ostree.go:369] Running captured: journalctl --list-boots',
#  'I1111 21:37:10.138106    4437 daemon.go:820] journalctl --list-boots:',
#  '-2 61d91031e3fe46c7997ade51641917e9 Wed 2020-11-11 16:46:26 UTC—Wed 2020-11-11 16:48:22 UTC',
#  '-1 dc74d33fdcbc41849bf1f5013f48dbb5 Wed 2020-11-11 16:51:58 UTC—Wed 2020-11-11 21:32:07 UTC',
#  ' 0 3b880fc52ade439a8935bbd6edbb9cc2 Wed 2020-11-11 21:36:39 UTC—Wed 2020-11-11 21:37:10 UTC',
#  'I1111 21:37:10.138125    4437 daemon.go:567] Starting MachineConfigDaemon',
#  'I1111 21:37:10.138246    4437 daemon.go:574] Enabling Kubelet Healthz Monitor',
#  '2020/11/11 21:37:39 provider.go:328: unable to retrieve authentication information for tokens: Post https://172.30.0.1:443/apis/authentication.k8s.io/v1/tokenreviews: dial tcp 172.30.0.1:443: i/o timeout',
#  "'''I1111 213740.052669    4437 trace.go116] Trace[646203300] 'Reflector ListAndWatch' namek8s.io/client-go/informers/factory.go135 (started 2020-11-11 213710.050563163 +0000 UTC m=+0.625024585) (total time 30.002046689s)'''",
#  'Trace[646203300]: [30.002046689s] [30.002046689s] END',
#  'E1111 21:37:40.052721    4437 reflector.go:178] k8s.io/client-go/informers/factory.go:135: Failed to list *v1.Node: Get https://172.30.0.1:443/api/v1/nodes?limit=500&resourceVersion=0: dial tcp 172.30.0.1:443: i/o timeout',
#  "'''I1111 213740.053200    4437 trace.go116] Trace[1747278511] 'Reflector ListAndWatch' namegithub.com/openshift/machine-config-operator/pkg/generated/informers/externalversions/factory.go101 (started 2020-11-11 213710.050671738 +0000 UTC m=+0.625133165) (total time 30.002502649s)'''",
#  'Trace[1747278511]: [30.002502649s] [30.002502649s] END',
#  'E1111 21:37:40.053242    4437 reflector.go:178] github.com/openshift/machine-config-operator/pkg/generated/informers/externalversions/factory.go:101: Failed to list *v1.MachineConfig: Get https://172.30.0.1:443/apis/machineconfiguration.openshift.io/v1/machineconfigs?limit=500&resourceVersion=0: dial tcp 172.30.0.1:443: i/o timeout',
#  'I1111 21:37:41.096832    4437 daemon.go:766] Current config: rendered-worker-1e91fa86f1c8f66fffd9b67ddc4caa81',
#  'I1111 21:37:41.097213    4437 daemon.go:767] Desired config: rendered-worker-db7587ea9813133d6a0afc32f718af56',
#  'I1111 21:37:41.104858    4437 update.go:1419] Disk currentConfig rendered-worker-db7587ea9813133d6a0afc32f718af56 overrides node annotation rendered-worker-1e91fa86f1c8f66fffd9b67ddc4caa81',
#  'I1111 21:37:41.108746    4437 daemon.go:1013] Validating against pending config rendered-worker-db7587ea9813133d6a0afc32f718af56',
#  'I1111 21:37:41.593480    4437 daemon.go:1029] Validated on-disk state',
#  'I1111 21:37:41.610137    4437 daemon.go:1063] Completing pending config rendered-worker-db7587ea9813133d6a0afc32f718af56',
#  'I1111 21:37:41.628721    4437 update.go:1419] completed update for config rendered-worker-db7587ea9813133d6a0afc32f718af56',
#  'I1111 21:37:41.632414    4437 daemon.go:1079] In desired config rendered-worker-db7587ea9813133d6a0afc32f718af56',
#  "'''2020/11/11 213741 oauthproxy.go200 mapping path '/' => upstream 'http//127.0.0.18797/''''",
#  '2020/11/11 21:37:41 oauthproxy.go:227: OAuthProxy configured for  Client ID: system:serviceaccount:openshift-machine-config-operator:machine-config-daemon',
#  '2020/11/11 21:37:41 oauthproxy.go:237: Cookie settings: name:_oauth_proxy secure(https):true httponly:true expiry:168h0m0s domain:<default> refresh:disabled',
#  '2020/11/11 21:37:41 http.go:61: HTTP: listening on 127.0.0.1:4180',
#  'I1111 21:37:41.990110    5048 dynamic_serving_content.go:129] Starting serving::/etc/tls/private/tls.crt::/etc/tls/private/tls.key',
#  '2020/11/11 21:37:41 http.go:107: HTTPS: listening on [::]:9001',
#  '2020/11/11 21:47:47 server.go:3055: http: TLS handshake error from 192.241.215.97:47462: EOF',
#  '2020/11/11 22:47:25 server.go:3055: http: TLS handshake error from 209.141.61.233:41334: read tcp 192.12.185.132:9001->209.141.61.233:41334: read: connection reset by peer',
#  'E1112 00:26:31.339551    4437 reflector.go:380] k8s.io/client-go/informers/factory.go:135: Failed to watch *v1.Node: Get https://172.30.0.1:443/api/v1/nodes?allowWatchBookmarks=true&resourceVersion=1836972&timeout=8m39s&timeoutSeconds=519&watch=true: dial tcp 172.30.0.1:443: connect: connection refused',
#  'E1112 04:12:07.185094    4437 reflector.go:380] github.com/openshift/machine-config-operator/pkg/generated/informers/externalversions/factory.go:101: Failed to watch *v1.MachineConfig: Get https://172.30.0.1:443/apis/machineconfiguration.openshift.io/v1/machineconfigs?allowWatchBookmarks=true&resourceVersion=2037273&timeout=8m12s&timeoutSeconds=492&watch=true: dial tcp 172.30.0.1:443: connect: connection refused',
#  'E1112 04:33:40.552443    4437 reflector.go:380] k8s.io/client-go/informers/factory.go:135: Failed to watch *v1.Node: Get https://172.30.0.1:443/api/v1/nodes?allowWatchBookmarks=true&resourceVersion=2070240&timeout=8m45s&timeoutSeconds=525&watch=true: dial tcp 172.30.0.1:443: connect: connection refused']

# %% [markdown]
# ### Conclusion
#
# In this notebook, we have shown how to read a sample data set of logs from our operate first elasticsearch instance and provided some priliminary insight into the structure of the data and how to look at isolate logs by specific pods, or other identifiers.
